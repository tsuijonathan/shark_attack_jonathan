# %%
import pandas as pd
df = pd.read_csv('shark_final_df.csv')

# %%
filtered_df = df[(df['sex'] == 'M') & (df['country'] == 'South Africa') & (df['fatal'] == 'no')]
filtered_df
# Out:
#             date  year       country       activity sex  age fatal  \
# 20   05-Jan-2024  2024  South Africa        fishing   M   62    no
# 81   03-May-2023  2023  South Africa        surfing   M   50    no
# 82   01-May-2023  2023  South Africa         diving   M   39    no
# 102  30-Dec-2022  2022  South Africa         diving   M   26    no
# 164  09-Jan-2022  2022  South Africa        fishing   M   15    no
# 201  14-Jul-2021  2021  South Africa        surfing   M   38    no
# 224  14-Apr-2021  2021  South Africa        fishing   M   38    no
# 339  09-Nov-2019  2019  South Africa        fishing   M   15    no
# 377  10-Jul-2019  2019  South Africa        surfing   M   20    no
# 410  05-Mar-2019  2019  South Africa        fishing   M   46    no
# 417  02-Feb-2019  2019  South Africa        fishing   M   15    no
# 432  11-Nov-2018  2018  South Africa        fishing   M   41    no
# 488  12-May-2018  2018  South Africa        surfing   M   15    no
# ...
